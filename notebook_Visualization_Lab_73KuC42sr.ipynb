# %% [markdown]
# <center>
#     <img src="https://gitlab.com/ibm/skills-network/courses/placeholder101/-/raw/master/labs/module%201/images/IDSNlogo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# # **Data Visualization Lab**

# %% [markdown]
# Estimated time needed: **45 to 60** minutes

# %% [markdown]
# In this assignment you will be focusing on the visualization of data.
#
# The data set will be presented to you in the form of a RDBMS.
#
# You will have to use SQL queries to extract the data.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab you will perform the following:

# %% [markdown]
# *   Visualize the distribution of data.
#
# *   Visualize the relationship between two features.
#
# *   Visualize composition of data.
#
# *   Visualize comparison of data.

# %% [markdown]
# <hr>

# %% [markdown]
# ## Demo: How to work with database

# %% [markdown]
# Download database file.

# %%
# !wget https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m4_survey_data.sqlite
# Out:
# --2021-09-02 23:12:28--  https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m4_survey_data.sqlite
# Resolving cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)... 198.23.119.245
# Connecting to cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)|198.23.119.245|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 36679680 (35M) [application/octet-stream]
# Saving to: ‘m4_survey_data.sqlite.2’
#
# m4_survey_data.sqli 100%[===================>]  34.98M  53.6MB/s    in 0.7s
#
# 2021-09-02 23:12:29 (53.6 MB/s) - ‘m4_survey_data.sqlite.2’ saved [36679680/36679680]

# %% [markdown]
# Connect to the database.

# %%
import sqlite3
conn = sqlite3.connect("m4_survey_data.sqlite") # open a database connection

# %% [markdown]
# Import pandas module.

# %%
import pandas as pd

# %% [markdown]
# ## Demo: How to run an sql query

# %%
# print how many rows are there in the table named 'master'
QUERY = """
SELECT COUNT(*)
FROM master
"""

# the read_sql_query runs the sql query and returns the data as a dataframe
df = pd.read_sql_query(QUERY,conn)
df.head()
# Out:
#    COUNT(*)
# 0     11398

# %% [markdown]
# ## Demo: How to list all tables

# %%
# print all the tables names in the database
QUERY = """
SELECT name as Table_Name FROM
sqlite_master WHERE
type = 'table'
"""
# the read_sql_query runs the sql query and returns the data as a dataframe
pd.read_sql_query(QUERY,conn)
# Out:
#                 Table_Name
# 0                 EduOther
# 1                  DevType
# 2                  LastInt
# 3               JobFactors
# 4                 WorkPlan
# 5            WorkChallenge
# 6       LanguageWorkedWith
# 7   LanguageDesireNextYear
# 8       DatabaseWorkedWith
# 9   DatabaseDesireNextYear
# 10      PlatformWorkedWith
# 11  PlatformDesireNextYear
# 12      WebFrameWorkedWith
# 13  WebFrameDesireNextYear
# 14      MiscTechWorkedWith
# 15  MiscTechDesireNextYear
# 16              DevEnviron
# 17              Containers
# 18               SOVisitTo
# 19            SONewContent
# 20                  Gender
# 21               Sexuality
# 22               Ethnicity
# 23                  master

# %% [markdown]
# ## Demo: How to run a group by query

# %%
QUERY = """
SELECT Age,COUNT(*) as count
FROM master
group by age
order by age
"""
pd.read_sql_query(QUERY,conn)
# Out:
#      Age  count
# 0    NaN    287
# 1   16.0      3
# 2   17.0      6
# 3   18.0     29
# 4   19.0     78
# 5   20.0    109
# 6   21.0    203
# 7   22.0    406
# 8   23.0    581
# 9   24.0    679
# 10  25.0    738
# 11  26.0    720
# 12  27.0    724
# 13  28.0    787
# 14  29.0    697
# 15  30.0    651
# 16  31.0    531
# 17  32.0    489
# 18  33.0    483
# 19  34.0    395
# 20  35.0    393
# 21  36.0    308
# 22  37.0    280
# 23  38.0    279
# 24  39.0    232
# 25  40.0    187
# 26  41.0    136
# 27  42.0    162
# 28  43.0    100
# 29  44.0     95
# 30  45.0     85
# 31  46.0     66
# 32  47.0     68
# 33  48.0     64
# 34  49.0     66
# 35  50.0     57
# 36  51.0     29
# 37  52.0     41
# 38  53.0     32
# 39  54.0     26
# 40  55.0     13
# 41  56.0     16
# 42  57.0     11
# 43  58.0     12
# 44  59.0     11
# 45  60.0      2
# 46  61.0     10
# 47  62.0      5
# 48  63.0      7
# 49  65.0      2
# 50  66.0      1
# 51  67.0      1
# 52  69.0      1
# 53  71.0      2
# ...

# %% [markdown]
# ## Demo: How to describe a table

# %%
table_name = 'master'  # the table you wish to describe

QUERY = """
SELECT sql FROM sqlite_master
WHERE name= '{}'
""".format(table_name)

df = pd.read_sql_query(QUERY,conn)
print(df.iat[0,0])
# Out:
# CREATE TABLE "master" (
# "index" INTEGER,
#   "Respondent" INTEGER,
#   "MainBranch" TEXT,
#   "Hobbyist" TEXT,
#   "OpenSourcer" TEXT,
#   "OpenSource" TEXT,
#   "Employment" TEXT,
#   "Country" TEXT,
#   "Student" TEXT,
#   "EdLevel" TEXT,
#   "UndergradMajor" TEXT,
#   "OrgSize" TEXT,
#   "YearsCode" TEXT,
#   "Age1stCode" TEXT,
#   "YearsCodePro" TEXT,
#   "CareerSat" TEXT,
#   "JobSat" TEXT,
#   "MgrIdiot" TEXT,
#   "MgrMoney" TEXT,
#   "MgrWant" TEXT,
#   "JobSeek" TEXT,
#   "LastHireDate" TEXT,
#   "FizzBuzz" TEXT,
#   "ResumeUpdate" TEXT,
#   "CurrencySymbol" TEXT,
#   "CurrencyDesc" TEXT,
#   "CompTotal" REAL,
#   "CompFreq" TEXT,
#   "ConvertedComp" REAL,
#   "WorkWeekHrs" REAL,
#   "WorkRemote" TEXT,
#   "WorkLoc" TEXT,
#   "ImpSyn" TEXT,
#   "CodeRev" TEXT,
#   "CodeRevHrs" REAL,
#   "UnitTests" TEXT,
#   "PurchaseHow" TEXT,
#   "PurchaseWhat" TEXT,
#   "OpSys" TEXT,
#   "BlockchainOrg" TEXT,
#   "BlockchainIs" TEXT,
#   "BetterLife" TEXT,
#   "ITperson" TEXT,
# ...

# %% [markdown]
# # Hands-on Lab

# %% [markdown]
# ## Visualizing distribution of data

# %% [markdown]
# ### Histograms

# %% [markdown]
# Plot a histogram of `ConvertedComp.`

# %%
# your code goes here
QUERY = """
SELECT *
FROM master
"""

df = pd.read_sql_query(QUERY,conn)
df.head()
# Out:
#    index  Respondent                      MainBranch Hobbyist  \
# 0      0           4  I am a developer by profession       No
# 1      1           9  I am a developer by profession      Yes
# 2      2          13  I am a developer by profession      Yes
# 3      3          16  I am a developer by profession      Yes
# 4      4          17  I am a developer by profession      Yes
#
#                                          OpenSourcer  \
# 0                                              Never
# 1                         Once a month or more often
# 2  Less than once a month but more than once per ...
# 3                                              Never
# 4  Less than once a month but more than once per ...
#
#                                           OpenSource          Employment  \
# 0  The quality of OSS and closed source software ...  Employed full-time
# 1  The quality of OSS and closed source software ...  Employed full-time
# ...

# %%
df['ConvertedComp'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# ### Box Plots

# %% [markdown]
# Plot a box plot of `Age.`

# %%
# your code goes here
df['Age'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Visualizing relationships in data

# %% [markdown]
# ### Scatter Plots

# %% [markdown]
# Create a scatter plot of `Age` and `WorkWeekHrs.`

# %%
# your code goes here
df.plot(kind='scatter', x='Age', y='WorkWeekHrs', figsize=(10, 6), color='darkblue')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='WorkWeekHrs'>

# %% [markdown]
# ### Bubble Plots

# %% [markdown]
# Create a bubble plot of `WorkWeekHrs` and `CodeRevHrs`, use `Age` column as bubble size.

# %%
# your code goes here
df.plot(kind='scatter', x='WorkWeekHrs', y='CodeRevHrs', s='Age')
# Out:
# <AxesSubplot:xlabel='WorkWeekHrs', ylabel='CodeRevHrs'>

# %% [markdown]
# ## Visualizing composition of data

# %% [markdown]
# ### Pie Charts

# %% [markdown]
# Create a pie chart of the top 5 databases that respondents wish to learn next year. Label the pie chart with database names. Display percentages of each database on the pie chart.

# %%
import matplotlib.pyplot as plt

# %%
# your code goes here
QUERY = """
SELECT DatabaseDesireNextYear, Count(*) AS Total
FROM DatabaseDesireNextYear
GROUP BY DatabaseDesireNextYear
ORDER BY Total desc
"""

df_c = pd.read_sql_query(QUERY,conn)
df_ch = df_c.head()
df_ch.set_index('DatabaseDesireNextYear', inplace=True)
df_ch
# Out:
#                         Total
# DatabaseDesireNextYear
# PostgreSQL               4328
# MongoDB                  3649
# Redis                    3331
# MySQL                    3281
# Elasticsearch            2856

# %%
df_ch['Total'].plot(kind='pie',
                    figsize=(15, 6),
                    autopct='%1.1f%%', 
                    startangle=90,    
                    shadow=True,       
                    )
# Out:
# <AxesSubplot:ylabel='Total'>

# %% [markdown]
# ### Stacked Charts

# %% [markdown]
# Create a stacked chart of median `WorkWeekHrs` and `CodeRevHrs` for the age group 30 to 35.

# %%
# your code goes here
QUERY = """
SELECT WorkWeekhrs, CodeRevHrs
FROM Master
WHERE Age BETWEEN 30 AND 35
"""

df_sc = pd.read_sql_query(QUERY,conn)
df_sc.shape
# Out:
# (2942, 2)

# %%
#x = df_sc['WorkWeekHrs'].median()
#y = df_sc['CodeRevHrs'].median()
df_sc.median()

# %%
df_sc.plot(kind='area', figsize=(20, 10))
# Out:
# <AxesSubplot:>

# %%
QUERY = """
SELECT LanguageDesireNextYear, COUNT(*) AS Total
FROM LanguageDesireNextYear
GROUP BY LanguageDesireNextYear
ORDER BY Total desc
"""

df_l = pd.read_sql_query(QUERY,conn)
df_l
# Out:
#    LanguageDesireNextYear  Total
# 0              JavaScript   6630
# 1                HTML/CSS   5328
# 2                  Python   5239
# 3                     SQL   5012
# 4              TypeScript   4088
# 5                      C#   3591
# 6   Bash/Shell/PowerShell   3097
# 7                    Java   2953
# 8                      Go   2759
# 9                  Kotlin   1890
# 10                    C++   1633
# 11                   Rust   1520
# 12                    PHP   1457
# 13            WebAssembly   1397
# 14                  Swift   1179
# 15                   Ruby   1029
# 16                      C   1028
# 17                  Scala    879
# 18                      R    850
# 19              Other(s):    836
# 20                     F#    621
# 21                 Elixir    620
# 22                   Dart    610
# 23                Clojure    413
# 24               Assembly    336
# 25            Objective-C    310
# 26                 Erlang    310
# ...

# %%
QUERY = """
SELECT DatabaseWorkedWith, COUNT(*) AS Total
FROM DatabaseWorkedWith
GROUP BY DatabaseWorkedWith
ORDER BY Total desc
"""

df_lw = pd.read_sql_query(QUERY,conn)
df_lw
# Out:
#       DatabaseWorkedWith  Total
# 0                  MySQL   5469
# 1   Microsoft SQL Server   4110
# 2             PostgreSQL   4097
# 3                 SQLite   3248
# 4                MongoDB   3016
# 5                  Redis   2508
# 6          Elasticsearch   1954
# 7                 Oracle   1744
# 8                MariaDB   1709
# 9               Firebase   1314
# 10              DynamoDB    831
# 11             Other(s):    728
# 12             Cassandra    397
# 13             Couchbase    250

# %%
QUERY = """
SELECT *
FROM DatabaseWorkedWith
"""

df_lw1 = pd.read_sql_query(QUERY,conn)
ndf = df_lw1[df_lw1['Respondent'].duplicated(keep = 'first')]

# %%
ndf
# Out:
#        Respondent DatabaseWorkedWith
# 1               4             SQLite
# 3               9         PostgreSQL
# 4               9             SQLite
# 6              13           DynamoDB
# 7              13           Firebase
# ...           ...                ...
# 31364       25133         PostgreSQL
# 31366       25134              MySQL
# 31367       25134         PostgreSQL
# 31368       25134             SQLite
# 31373       25141              Redis
#
# [20430 rows x 2 columns]

# %%
import numpy as np
n_df = ndf.loc[ndf['DatabaseWorkedWith'] == 'MySQL']
n_df
# Out:
#        Respondent DatabaseWorkedWith
# 8              13              MySQL
# 11             16              MySQL
# 17             19              MySQL
# 24             22              MySQL
# 31             24              MySQL
# ...           ...                ...
# 31326       25109              MySQL
# 31332       25110              MySQL
# 31342       25120              MySQL
# 31356       25124              MySQL
# 31366       25134              MySQL
#
# [4188 rows x 2 columns]

# %% [markdown]
# ## Visualizing comparison of data

# %% [markdown]
# ### Line Chart

# %% [markdown]
# Plot the median `ConvertedComp` for all ages from 45 to 60.

# %%
# your code goes here
QUERY = """
SELECT ConvertedComp
FROM master
WHERE Age BETWEEN 45 AND 60
"""

df_lcc = pd.read_sql_query(QUERY,conn)
df_lcc.shape
# Out:
# (599, 1)

# %%
df_lcc.median()
# Out:
# ConvertedComp    100000.0
# dtype: float64

# %%
a = int(df_lcc.mean())
a
# Out:
# 187693

# %%
df_lcc['ConvertedComp'].replace(np.nan, a, inplace=True)

# %%
df_lcc.median()
# Out:
# ConvertedComp    104263.0
# dtype: float64

# %%
df_lcc.plot(kind='line', figsize=(12, 6))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Bar Chart

# %% [markdown]
# Create a horizontal bar chart using column `MainBranch.`

# %%
# your code goes here
df_bc = df['MainBranch'].value_counts().to_frame()
df_bc
# Out:
#                                                     MainBranch
# I am a developer by profession                           10618
# I am not primarily a developer, but I write cod...         780

# %%
df_bc.plot(kind='barh', figsize=(12, 6))
# Out:
# <AxesSubplot:>

# %%
QUERY = """
SELECT *
FROM DevType
GROUP BY DevType
ORDER BY Respondent DESC
"""

df_dt = pd.read_sql_query(QUERY,conn)
df_dt
# Out:
#     Respondent                                        DevType
# 0          129                                      Scientist
# 1          129                            Academic researcher
# 2           62                Marketing or sales professional
# 3           62  Data scientist or machine learning specialist
# 4           43                    Developer, game or graphics
# 5           26                                Product manager
# 6           26                                       Educator
# 7           20    Developer, embedded applications or devices
# 8           20                                       Designer
# 9           17                                        Student
# 10          13                           System administrator
# 11          13                            Senior executive/VP
# 12          13                            Engineering manager
# 13          13                     Engineer, site reliability
# ...

# %%
df_dt['DevType'].value_counts()
# Out:
# Developer, full-stack                            6928
# Developer, back-end                              6290
# Developer, front-end                             3920
# Developer, desktop or enterprise applications    2575
# Developer, mobile                                1959
# DevOps specialist                                1639
# Database administrator                           1413
# System administrator                             1202
# Designer                                          988
# Developer, QA or test                             911
# Developer, embedded applications or devices       854
# Engineer, data                                    832
# Data scientist or machine learning specialist     803
# Data or business analyst                          802
# Student                                           766
# Academic researcher                               556
# Educator                                          514
# ...

# %%
QUERY = """
SELECT Age, ConvertedComp
FROM master
WHERE Age BETWEEN 25 AND 30
"""

df_acc = pd.read_sql_query(QUERY,conn)
df_acc.head()
# Out:
#     Age  ConvertedComp
# 0  28.0        90000.0
# 1  26.0       455352.0
# 2  29.0        65277.0
# 3  27.0        20623.0
# 4  27.0       107000.0

# %%
df_acc1 = df_acc.set_index('Age')

# %%
ag = list(map(str, range(25, 31)))
ag
# Out:
# ['25', '26', '27', '28', '29', '30']

# %%
df_acc1.index = df_acc1.index.map(int)

# %%
df_acc.plot(kind='scatter', x = 'Age', y = 'ConvertedComp', figsize=(12, 6))
# Out:
# <AxesSubplot:xlabel='Age', ylabel='ConvertedComp'>

# %%
df_acc
# Out:
#        Age  ConvertedComp
# 0     28.0        90000.0
# 1     26.0       455352.0
# 2     29.0        65277.0
# 3     27.0        20623.0
# 4     27.0       107000.0
# ...    ...            ...
# 4312  26.0        35518.0
# 4313  26.0        26586.0
# 4314  25.0        19880.0
# 4315  25.0        80371.0
# 4316  30.0            NaN
#
# [4317 rows x 2 columns]

# %% [markdown]
# Close the database connection.

# %%
conn.close()

# %% [markdown]
# ## Authors

# %% [markdown]
# Ramesh Sannareddy

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# Rav Ahuja

# %% [markdown]
# ## Change Log

# %% [markdown]
# | Date (YYYY-MM-DD) | Version | Changed By        | Change Description                 |
# | ----------------- | ------- | ----------------- | ---------------------------------- |
# | 2020-10-17        | 0.1     | Ramesh Sannareddy | Created initial version of the lab |

# %% [markdown]
# Copyright © 2020 IBM Corporation. This notebook and its source code are released under the terms of the [MIT License](https://cognitiveclass.ai/mit-license?utm_medium=Exinfluencer\&utm_source=Exinfluencer\&utm_content=000026UJ\&utm_term=10006555\&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork21426264-2021-01-01\&cm_mmc=Email_Newsletter-\_-Developer_Ed%2BTech-\_-WW_WW-\_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264\&cm_mmca1=000026UJ\&cm_mmca2=10006555\&cm_mmca3=M12345678\&cvosrc=email.Newsletter.M12345678\&cvo_campaign=000026UJ).
